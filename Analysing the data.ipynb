# %%
import pandas as pd

# %%
seatbelt_df = pd.read_excel('RSA Data.xlsx', sheet_name = 0)
casualty_df = pd.read_excel('RSA Data.xlsx', sheet_name = 1)

# %%
seatbelt_df.head()
# Out:
#   Seat belt   Casualty  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0       Yes    Injured  1730  1658  1520  2097  2404  1890  1638  1699
# 1       Yes     Killed    55    49    42    44    41    39    35    22
# 2       Yes  Uninjured  1293  1157  1055  1599  1947  1639  1495  1568
# 3        No    Injured   184   144    70   103   103   103    84    88
# 4        No     Killed    38    37    14    12    21    13    12    14
#
#    Participant
# 0  Car drivers
# 1  Car drivers
# 2  Car drivers
# 3  Car drivers
# 4  Car drivers

# %%
casualty_df.head()
# Out:
#            Age   Sex     Participant Casualty  2005  2006  2007  2008  2009  \
# 0  0 - 5 years  Male     Pedestrians  Injured    36    32    28    54    35
# 1  0 - 5 years  Male     Pedestrians   Killed     3     1     0     1     3
# 2  0 - 5 years  Male  Pedal cyclists  Injured     0     0     2     0     2
# 3  0 - 5 years  Male  Pedal cyclists   Killed     0     0     0     0     0
# 4  0 - 5 years  Male  Motor cyclists  Injured     0     0     0     0     0
#
#    2010  2011  2012
# 0    41    39    40
# 1     3     0     0
# 2     5     3     1
# 3     0     1     0
# 4     0     0     0

# %%
seatbelt_df_new = pd.read_excel('Seatbelt_RSA_Data_after_OpenRefine.xls')

# %%
seatbelt_df_new.head(10)
# Out:
#   Seat belt   Casualty 2005.0 2006.0 2007.0 2008.0 2009.0 2010.0 2011.0  \
# 0       Yes    Injured   1730   1658   1520   2097   2404   1890   1638
# 1       Yes     Killed     55     49     42     44     41     39     35
# 2       Yes  Uninjured   1293   1157   1055   1599   1947   1639   1495
# 3        No    Injured    184    144     70    103    103    103     84
# 4        No     Killed     38     37     14     12     21     13     12
# 5        No  Uninjured     81     60     32     30     39     26     26
# 6   Unknown    Injured   1377   1241    917   1354   1393   1225    972
# 7   Unknown     Killed     37     44     32     43     44     26     14
# 8   Unknown  Uninjured   1252   1005    778   1195   1236   1245   1141
# 9   Unknown    Injured    962    716    888    663    292    288    291
#
#   2012.0  Participant
# 0   1699  Car drivers
# 1     22  Car drivers
# 2   1568  Car drivers
# 3     88  Car drivers
# 4     14  Car drivers
# 5     29  Car drivers
# ...

# %%
seatbelt_df_new.columns
# Out:
# Index(['Seat belt', 'Casualty', '2005.0', '2006.0', '2007.0', '2008.0',
#        '2009.0', '2010.0', '2011.0', '2012.0', 'Participant'],
#       dtype='object')

# %%
seatbelt_cleaned_df = pd.read_excel('Seatbelt_RSA_Data_after_my_excel_cleaning.xls')
seatbelt_cleaned_df.head()
# Out:
#   Seat belt   Casualty  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0       Yes    Injured  1730  1658  1520  2097  2404  1890  1638  1699
# 1       Yes     Killed    55    49    42    44    41    39    35    22
# 2       Yes  Uninjured  1293  1157  1055  1599  1947  1639  1495  1568
# 3       Yes        All  3078  2864  2617  3740  4392  3568  3168  3289
# 4        No    Injured   184   144    70   103   103   103    84    88
#
#    Participant
# 0  Car drivers
# 1  Car drivers
# 2  Car drivers
# 3  Car drivers
# 4  Car drivers

# %%
seatbelt_cleaned_df
# Out:
#    Seat belt   Casualty   2005   2006   2007   2008   2009   2010   2011  \
# 0        Yes    Injured   1730   1658   1520   2097   2404   1890   1638
# 1        Yes     Killed     55     49     42     44     41     39     35
# 2        Yes  Uninjured   1293   1157   1055   1599   1947   1639   1495
# 3        Yes        All   3078   2864   2617   3740   4392   3568   3168
# 4         No    Injured    184    144     70    103    103    103     84
# 5         No     Killed     38     37     14     12     21     13     12
# 6         No  Uninjured     81     60     32     30     39     26     26
# 7         No        All    303    241    116    145    163    142    122
# 8    Unknown    Injured   2339   1957   1805   2017   1685   1513   1263
# 9    Unknown     Killed     51     61     54     53     45     28     18
# 10   Unknown  Uninjured   1824   1641   1785   1863   1552   1495   1392
# 11   Unknown        All   4214   3659   3644   3933   3282   3036   2673
# ...

# %%
total_wearing_seatbelt = seatbelt_cleaned_df[(seatbelt_cleaned_df['Seat belt'] == 'Yes') & (seatbelt_cleaned_df['Casualty'] == 'All')]

# %%
'''killed_wearing_seatbelt = '''
print(seatbelt_cleaned_df[(seatbelt_cleaned_df['Seat belt'] == 'Yes') & (seatbelt_cleaned_df['Casualty'] == 'Killed') & (seatbelt_cleaned_df['Participant'] == 'Car drivers')])
# Out:
#   Seat belt Casualty 2005 2006 2007 2008 2009 2010 2011 2012  Participant
# 1       Yes   Killed   55   49   42   44   41   39   35   22  Car drivers

# %%
prop_killed_wearing_seatbelt = killed_wearing_seatbelt/total_wearing_seatbelt

# %%
print(prop_killed_wearing_seatbelt)
# Out:
#    Seat belt Casualty 2005 2006 2007 2008 2009 2010 2011 2012 Participant
# 1        NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 3        NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN
# 18       NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN         NaN

# %%
import matplotlib.pyplot as plt

# %%
concat_df = pd.concat([casualty_df['Participant'], casualty_df[2005], casualty_df[2006], casualty_df[2007], casualty_df[2008], casualty_df[2009], casualty_df[2010], casualty_df[2011], casualty_df[2012]], axis=1)
concat_df.head()
# Out:
#       Participant  2005  2006  2007  2008  2009  2010  2011  2012
# 0     Pedestrians    36    32    28    54    35    41    39    40
# 1     Pedestrians     3     1     0     1     3     3     0     0
# 2  Pedal cyclists     0     0     2     0     2     5     3     1
# 3  Pedal cyclists     0     0     0     0     0     0     1     0
# 4  Motor cyclists     0     0     0     0     0     0     0     0

# %%
grouped_df = concat_df.groupby(by='Participant').sum()
df = grouped_df.reset_index()

# %%
print(df)
# Out:
#         Participant  2005  2006  2007  2008  2009  2010  2011  2012
# 0       Car drivers  3668  3673  3353  4164  4171  3420  2911  3212
# 1    Car passengers  1895  1870  1923  2499  2675  2219  1863  2071
# 2    Motor cyclists   541   492   390   497   445   388   329   348
# 3  Other road users   924   914   761   786   697   694   637   560
# 4    Pedal cyclists   197   198   260   332   361   386   387   621
# 5       Pedestrians   982   946   929  1140  1093   950   964  1025

# %%
df.columns
# Out:
# Index(['Participant', 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 9 columns):
# Participant    6 non-null object
# 2005           6 non-null int64
# 2006           6 non-null int64
# 2007           6 non-null int64
# 2008           6 non-null int64
# 2009           6 non-null int64
# 2010           6 non-null int64
# 2011           6 non-null int64
# 2012           6 non-null int64
# dtypes: int64(8), object(1)
# memory usage: 512.0+ bytes

# %%
df_transpose = df.transpose()
df_transpose.columns = df_transpose.iloc[0]
df_transpose.head()
# Out:
# Participant  Car drivers  Car passengers  Motor cyclists  Other road users  \
# Participant  Car drivers  Car passengers  Motor cyclists  Other road users
# 2005                3668            1895             541               924
# 2006                3673            1870             492               914
# 2007                3353            1923             390               761
# 2008                4164            2499             497               786
#
# Participant  Pedal cyclists  Pedestrians
# Participant  Pedal cyclists  Pedestrians
# 2005                    197          982
# 2006                    198          946
# 2007                    260          929
# 2008                    332         1140

# %%
df1 = df_transpose.drop(index='Participant')
df1.head()
# Out:
# Participant Car drivers Car passengers Motor cyclists Other road users  \
# 2005               3668           1895            541              924
# 2006               3673           1870            492              914
# 2007               3353           1923            390              761
# 2008               4164           2499            497              786
# 2009               4171           2675            445              697
#
# Participant Pedal cyclists Pedestrians
# 2005                   197         982
# 2006                   198         946
# 2007                   260         929
# 2008                   332        1140
# 2009                   361        1093

# %%
df1.columns
# Out:
# Index(['Car drivers', 'Car passengers', 'Motor cyclists', 'Other road users',
#        'Pedal cyclists', 'Pedestrians'],
#       dtype='object', name='Participant')

# %%
df1 = df1.reset_index(level=0)
df1.head()
# Out:
# Participant  index Car drivers Car passengers Motor cyclists Other road users  \
# 0             2005        3668           1895            541              924
# 1             2006        3673           1870            492              914
# 2             2007        3353           1923            390              761
# 3             2008        4164           2499            497              786
# 4             2009        4171           2675            445              697
#
# Participant Pedal cyclists Pedestrians
# 0                      197         982
# 1                      198         946
# 2                      260         929
# 3                      332        1140
# 4                      361        1093

# %%
new_df = df1.rename(index=str, columns={'index': 'Year'})
new_df.head()
# Out:
# Participant  Year Car drivers Car passengers Motor cyclists Other road users  \
# 0            2005        3668           1895            541              924
# 1            2006        3673           1870            492              914
# 2            2007        3353           1923            390              761
# 3            2008        4164           2499            497              786
# 4            2009        4171           2675            445              697
#
# Participant Pedal cyclists Pedestrians
# 0                      197         982
# 1                      198         946
# 2                      260         929
# 3                      332        1140
# 4                      361        1093

# %%
plt.plot(new_df['Year'], new_df['Car drivers'], color='red')

# %%
plt.plot(new_df['Year'], new_df['Car drivers'], color='red')
plt.xlabel('Year')
plt.ylabel("No. of people killed or injured (In 1000's)")
plt.title('Number of car drivers killed or injured between 2005 and 2012\n')
plt.yticks([3000, 3200, 3400, 3600, 3800, 4000, 4200], [3, 3.2, 3.4, 3.6, 3.8, 4, 4.2])
# Out:
# ([<matplotlib.axis.YTick at 0x16b7d397eb8>,
# ...
#  <a list of 7 Text yticklabel objects>)

# %%
df1.plot()

# %%
df_transpose.drop(index='Participant').plot()
plt.xlabel('Year')
plt.ylabel("Number of casualties")
plt.title('Number of casualties between 2005 and 2012 by their mode of transport\n')
ax = plt.subplot(111)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.yticks([3000, 3200, 3400, 3600, 3800, 4000, 4200], [3, 3.2, 3.4, 3.6, 3.8, 4, 4.2])
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
import pandas as pd

# %%
seatbelt = pd.read_excel('RSA Data.xlsx', sheet_name = 0)

# %%
seatbelt.head()
# Out:
#   Seat belt   Casualty  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0       Yes    Injured  1730  1658  1520  2097  2404  1890  1638  1699
# 1       Yes     Killed    55    49    42    44    41    39    35    22
# 2       Yes  Uninjured  1293  1157  1055  1599  1947  1639  1495  1568
# 3        No    Injured   184   144    70   103   103   103    84    88
# 4        No     Killed    38    37    14    12    21    13    12    14
#
#    Participant
# 0  Car drivers
# 1  Car drivers
# 2  Car drivers
# 3  Car drivers
# 4  Car drivers

# %%
seatbelt.replace(to_replace='Not stated', value='Unknown', inplace=True)

# %%
seat_df = seatbelt.groupby(by=[ 'Participant', 'Seat belt', 'Casualty']).sum()

# %%
seat_df.head()
# Out:
#                                  2005  2006  2007  2008  2009  2010  2011  \
# Participant Seat belt Casualty
# Car drivers No        Injured     184   144    70   103   103   103    84
#                       Killed       38    37    14    12    21    13    12
#                       Uninjured    81    60    32    30    39    26    26
#             Unknown   Injured    2339  1957  1805  2017  1685  1513  1263
#                       Killed       51    61    54    53    45    28    18
#
#                                  2012
# Participant Seat belt Casualty
# Car drivers No        Injured      88
#                       Killed       14
#                       Uninjured    29
#             Unknown   Injured    1473
#                       Killed       28

# %%
seatbelt_dataframe = seat_df.reset_index()
seatbelt_dataframe.head()
# Out:
#    Participant Seat belt   Casualty  2005  2006  2007  2008  2009  2010  2011  \
# 0  Car drivers        No    Injured   184   144    70   103   103   103    84
# 1  Car drivers        No     Killed    38    37    14    12    21    13    12
# 2  Car drivers        No  Uninjured    81    60    32    30    39    26    26
# 3  Car drivers   Unknown    Injured  2339  1957  1805  2017  1685  1513  1263
# 4  Car drivers   Unknown     Killed    51    61    54    53    45    28    18
#
#    2012
# 0    88
# 1    14
# 2    29
# 3  1473
# 4    28

# %%
#seatbelt_dataframe.loc[3] = 
['Car drivers', 'No', 'All', seatbelt_dataframe[[2005, 2006, 2006, 2007, 2008, 2009, 2010, 2011, 2012]].sum(axis=1)]
#seatbelt_dataframe.head(10)
# Out:
# ['Car drivers', 'No', 'All', 0                                     1023
#  1                                      198
#  2                                      383
#  3                                        0
#  4                                      399
#  5                                    14767
#  6                                    16294
#  7                                      376
#  8                                    12910
#  9                                      383
#  10                                      34
#  11                      ..................
#  12                                    4982
#  13                                     142
#  14    ....................................
#  15                                    5737
#  16                                     113
#  17                      ..................
#  dtype: object]

# %%
sex_df = pd.concat([casualty_df['Sex'], casualty_df[2005], casualty_df[2006], casualty_df[2007], casualty_df[2008], casualty_df[2009], casualty_df[2010], casualty_df[2011], casualty_df[2012]], axis=1)
sex_df.head(10)
# Out:
#     Sex  2005  2006  2007  2008  2009  2010  2011  2012
# 0  Male    36    32    28    54    35    41    39    40
# 1  Male     3     1     0     1     3     3     0     0
# 2  Male     0     0     2     0     2     5     3     1
# 3  Male     0     0     0     0     0     0     1     0
# 4  Male     0     0     0     0     0     0     0     0
# 5  Male     0     0     0     0     0     0     0     0
# 6  Male     1     0     0     0     0     0     0     0
# 7  Male     0     0     0     0     0     0     0     0
# 8  Male    52    51    69    97    85    68    54    83
# 9  Male     0     4     2     0     2     0     1     0

# %%
grouped = sex_df.groupby(by=['Sex']).sum()
grouped.head()
# Out:
#         2005  2006  2007  2008  2009  2010  2011  2012
# Sex
# Female  3233  3365  3242  3983  4018  3486  2992  3304
# Male    4974  4728  4374  5435  5424  4571  4099  4533

# %%
grouped.reset_index()
# Out:
#       Sex  2005  2006  2007  2008  2009  2010  2011  2012
# 0  Female  3233  3365  3242  3983  4018  3486  2992  3304
# 1    Male  4974  4728  4374  5435  5424  4571  4099  4533

# %%
trans = grouped.transpose()
trans.head()
# Out:
# Sex   Female  Male
# 2005    3233  4974
# 2006    3365  4728
# 2007    3242  4374
# 2008    3983  5435
# 2009    4018  5424

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
#     control on the  appearance. Line properties and *fmt* can be mixed.
# ...

# %%
plt.plot(trans)
plt.xlabel('Year')
plt.ylabel('Number of casualties')
plt.title('Number of male / female casualties between 2005 and 2012\n')
# Out:
# Text(0.5,1,'Number of male / female casualties between 2005 and 2012\n')

# %%
import pandas as pd

# %%
seat = pd.read_excel('Seatbelt_RSA_Data_after_my_excel_cleaning.xls')

# %%
seat.head()
# Out:
#   Seat belt   Casualty  2005  2006  2007  2008  2009  2010  2011  2012  \
# 0       Yes    Injured  1730  1658  1520  2097  2404  1890  1638  1699
# 1       Yes     Killed    55    49    42    44    41    39    35    22
# 2       Yes  Uninjured  1293  1157  1055  1599  1947  1639  1495  1568
# 3       Yes        All  3078  2864  2617  3740  4392  3568  3168  3289
# 4        No    Injured   184   144    70   103   103   103    84    88
#
#    Participant
# 0  Car drivers
# 1  Car drivers
# 2  Car drivers
# 3  Car drivers
# 4  Car drivers

# %%
all_car_yes = seat.loc[(seat['Seat belt'] == 'Yes') & (seat['Casualty'] == 'All') & (seat['Participant'] == 'Car drivers')]

# %%
all_car_yes.columns
# Out:
# Index([  'Seat belt',    'Casualty',          2005,          2006,
#                 2007,          2008,          2009,          2010,
#                 2011,          2012, 'Participant'],
#       dtype='object')

# %%
all_car_yes = all_car_yes.drop(['Seat belt', 'Casualty', 'Participant'], axis=1)

# %%
all_car_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 3 to 3
# Data columns (total 8 columns):
# 2005    1 non-null object
# 2006    1 non-null object
# 2007    1 non-null object
# 2008    1 non-null object
# 2009    1 non-null object
# 2010    1 non-null object
# 2011    1 non-null object
# 2012    1 non-null object
# dtypes: object(8)
# memory usage: 152.0+ bytes

# %%
all_car_yes = all_car_yes.applymap(int)

# %%
all_car_yes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 3 to 3
# Data columns (total 8 columns):
# 2005    1 non-null int64
# 2006    1 non-null int64
# 2007    1 non-null int64
# 2008    1 non-null int64
# 2009    1 non-null int64
# 2010    1 non-null int64
# 2011    1 non-null int64
# 2012    1 non-null int64
# dtypes: int64(8)
# memory usage: 152.0 bytes

# %%
all_car = seat.loc[(seat['Seat belt'] == 'All') & (seat['Casualty'] == 'All') & (seat['Participant'] == 'Car drivers')]

# %%
all_car = all_car.drop(['Seat belt', 'Casualty', 'Participant'], axis=1)

# %%
all_car = all_car.applymap(int)

# %%
all_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 15 to 15
# Data columns (total 8 columns):
# 2005    1 non-null int64
# 2006    1 non-null int64
# 2007    1 non-null int64
# 2008    1 non-null int64
# 2009    1 non-null int64
# 2010    1 non-null int64
# 2011    1 non-null int64
# 2012    1 non-null int64
# dtypes: int64(8)
# memory usage: 152.0 bytes

# %%
all_car_yes/all_car
# Out:
#     2005  2006  2007  2008  2009  2010  2011  2012
# 3    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 15   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %%
all_car_yes.iloc[0]/all_car.iloc[0]
# Out:
# 2005    0.202633
# 2006    0.211709
# 2007    0.205191
# 2008    0.239192
# 2009    0.280209
# 2010    0.264453
# 2011    0.265638
# 2012    0.253195
# dtype: float64
